# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/Users/vinay/Documents/ml-learn/Exploratory-Data-Analysis-Projects/kidney_disease.csv")

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (400, 26)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    str
#  7   pc              335 non-null    str
#  8   pcc             396 non-null    str
#  9   ba              396 non-null    str
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    str
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='str')

# %%
df.drop('id', axis = 1, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='str')

# %%
df.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# ...

# %%
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                   str
# pc                    str
# pcc                   str
# ba                    str
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                   str
# wc                    str
# rc                    str
# htn                   str
# dm                    str
# cad                   str
# appet                 str
# pe                    str
# ane                   str
# classification        str
# dtype: object

# %%
df['pcv']
# Out:
# 0      44
# 1      38
# 2      31
# 3      32
# 4      35
#        ..
# 395    47
# 396    54
# 397    49
# 398    51
# 399    53
# Name: pcv, Length: 400, dtype: str

# %%
df['pcv'].unique()
# Out:
# <StringArray>
# [  '44',   '38',   '31',   '32',   '35',   '39',   '36',   '33',   '29',
#    '28',    nan,   '16',   '24',   '37',   '30',   '34',   '40',   '45',
#    '27',   '48',  '\t?',   '52',   '14',   '22',   '18',   '42',   '17',
#    '46',   '23',   '19',   '25',   '41',   '26',   '15',   '21',   '43',
#    '20', '\t43',   '47',    '9',   '49',   '50',   '53',   '51',   '54']
# Length: 45, dtype: str

# %%
# Due to some string values in the column its an object
# Still we want to convert it numerically

# %%
df['pcv'] = pd.to_numeric(df['pcv'], errors = "coerce")
# Coerce means supressing or ignoring the error

# %%
df['pcv'].dtype
# Out:
# dtype('float64')

# %%
df['pcv'].unique()
# Out:
# array([44., 38., 31., 32., 35., 39., 36., 33., 29., 28., nan, 16., 24.,
#        37., 30., 34., 40., 45., 27., 48., 52., 14., 22., 18., 42., 17.,
#        46., 23., 19., 25., 41., 26., 15., 21., 43., 20., 47.,  9., 49.,
#        50., 53., 51., 54.])

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='str')

# %%
df['wc'] = pd.to_numeric(df['wc'], errors = 'coerce')

# %%
df['wc'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                   str
# pc                    str
# pcc                   str
# ba                    str
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv               float64
# wc                float64
# rc                    str
# htn                   str
# dm                    str
# cad                   str
# appet                 str
# pe                    str
# ane                   str
# classification        str
# dtype: object

# %%
df['rc']
# Out:
# 0      5.2
# 1      NaN
# 2      NaN
# 3      3.9
# 4      4.6
#       ...
# 395    4.9
# 396    6.2
# 397    5.4
# 398    5.9
# 399    6.1
# Name: rc, Length: 400, dtype: str

# %%
df['rc'] = pd.to_numeric(df['rc'], errors = 'coerce')

# %%
df['rc'].dtype
# Out:
# dtype('float64')

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
cat_cols
# Out:
# []

# %%
num_cols = [col for col in df.columns if df[col].dtype != 'object']
num_cols
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
for col in cat_cols:
    print(f"{col} has {df[col].unique()}\n")

# %%
df['dm'].replace(to_replace={' yes':'yes', '\tyes':'yes', '\tno' : 'no'}, inplace=True)
# Out:
# 0      yes
# 1       no
# 2      yes
# 3       no
# 4       no
#       ...
# 395     no
# 396     no
# 397     no
# 398     no
# 399     no
# Name: dm, Length: 400, dtype: str

# %%
df['dm'].unique()
# Out:
# <StringArray>
# ['yes', 'no', ' yes', '\tno', '\tyes', nan]
# Length: 6, dtype: str

# %%
for col in cat_cols:
    print(f"{col} has {df[col].unique()}\n")

# %%
df['cad'].replace(to_replace = {'\tno' : 'no'}, inplace = True)
# Out:
# 0      no
# 1      no
# 2      no
# 3      no
# 4      no
#        ..
# 395    no
# 396    no
# 397    no
# 398    no
# 399    no
# Name: cad, Length: 400, dtype: str

# %%
df['cad'].unique()
# Out:
# <StringArray>
# ['no', 'yes', '\tno', nan]
# Length: 4, dtype: str

# %%
df['classification'].replace(to_replace = {'ckd\t' : 'ckd'}, inplace = True)
# Out:
# 0         ckd
# 1         ckd
# 2         ckd
# 3         ckd
# 4         ckd
#         ...
# 395    notckd
# 396    notckd
# 397    notckd
# 398    notckd
# 399    notckd
# Name: classification, Length: 400, dtype: str

# %%
for col in cat_cols:
    print(f"{col} has {df[col].unique()}\n")

# %%
# Univariate analysis

plt.figure(figsize = (10, 5))
sns.histplot(df['age'].dropna(), kde=True, bins=20, color='blue')
plt.title("Dist of Age")
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='str')

# %%
sns.boxplot(x = 'classification', y = 'bu', data = df, palette = 'viridis')
# Out:
# <Axes: xlabel='classification', ylabel='bu'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='str')

# %%
sns.countplot(x = "ane", data = df, palette= 'pastel')
# Out:
# <Axes: xlabel='ane', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='str')

# %%
df['appet']
# Out:
# 0      good
# 1      good
# 2      poor
# 3      poor
# 4      good
#        ...
# 395    good
# 396    good
# 397    good
# 398    good
# 399    good
# Name: appet, Length: 400, dtype: str

# %%
df.appet.value_counts().plot.pie(autopct = '%1.1f%%')
# Out:
# <Axes: >

# %%
df.appet.value_counts().plot.pie(autopct = '%1.1f%%', colors=["lightcoral", "lightgreen"], explode = (0,0.1), shadow = True, startangle = 90)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='str')

# %%
df['pcc'].value_counts()
# Out:
# pcc
# notpresent    354
# present        42
# Name: count, dtype: int64

# %%
df['dm'].value_counts().plot.pie(autopct = "%1.1f%%", wedgeprops = dict(width = 0.9))
# Out:
# <Axes: >

# %%
# BiVariate Analysis
sns.scatterplot(x = 'age', y = 'bp', data = df)
# Out:
# <Axes: xlabel='age', ylabel='bp'>

# %%
# Age is Increasing then BP also increasing

# %%
# BiVariate Analysis
sns.scatterplot(x = 'age', y = 'bp', data = df, hue = 'classification')
# Out:
# <Axes: xlabel='age', ylabel='bp'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='str')

# %%
cols = ['age', 'bp', 'bgr', 'classification']
g = sns.PairGrid(df[cols], hue='classification', palette = 'coolwarm')
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, cmap = 'Blues_d')
g.map_diag(sns.histplot)
g.add_legend()
plt.title("Pairgrid for selected columns")
# Out:
# Text(0.5, 1.0, 'Pairgrid for selected columns')
